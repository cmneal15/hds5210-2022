# %% [markdown]
# # Week 12 - Earn-Back Points Assignment #2
#
# These exercises are entirely optional, but they provide good practice. And you can use them to earn extra points toward your semester grade.  Completing all the questions in this assignment correctly will earn you back 8 points.
#
# There will be 2 more assignments like this between now and the end of the semester, giving you the opportunity to earn back a total of 32 points.
#
# **If anything about the above rules is unclear, please message me on Canvas or via email**

# %% [markdown]
# ---

# %% [markdown]
# ## Introduction
#
# The Centers for Medicare and Medicaid Services (CMS) provides lots of information online including a general directory of hospitals in the US. For this set of exercises, we'll be working with a file referred to as [Hospital General Information](https://data.cms.gov/provider-data/dataset/xubh-q36u). **Download this file as a CSV and upload it to your week 13 directory on Jupyter.**
#
# Each of these exercises will involve finding an answer to a specific question and then submitting that.  Your answers must be computed using Python code within this notebook to earn full credit.
#
# You do not need to write functions to compute the answers and do not need to provide any special documentation. You can simply calculate the answers inline in the notebook and then submit your answers using the `answers` dictionary, similar to how most of our part 1 assignments work.

# %%
import pandas as pd
answers = {}
df = pd.read_csv('Hospital_General_Information.csv')

# %% [markdown]
# ---

# %% [markdown]
# ## Tips
#
# Before you get started, I want to show you a pattern that you might find useful. In the example below, I'm going to summarize a simple data frame, determine which name occurs most often, how often that is, and what the percent of total that represents.  This can be a useful pattern in general and you should be able to apply it below.

# %%
df = pd.DataFrame([
    ['Boal','Paul',45],
    ['Boal','Anny',47],
    ['Boal','James',75],
    ['Lester','Sarahlynn',48],
    ['Lester','Carolynn',70]
], columns=['Last Name','First Name','Age'])

df
# Out:
#   Last Name First Name  Age
# 0      Boal       Paul   45
# 1      Boal       Anny   47
# 2      Boal      James   75
# 3    Lester  Sarahlynn   48
# 4    Lester   Carolynn   70

# %%
# Which family (based on Last Name) has the most people?

# 1. Group by Last Name
# 2. Count how many people are in each family
# 3. Sort by value


by_last_name = df.groupby('Last Name')
family_count = by_last_name['Last Name'].count()
family_sorted = family_count.sort_values(ascending=False)

family_sorted
# Out:
# Last Name
# Boal      3
# Lester    2
# Name: Last Name, dtype: int64

# %%
# 4. Extract the "index" (aka Last Name)
# 5. Choose the first value

top_family = list(family_sorted.index)[0]
top_family
# Out:
# 'Boal'

# %%
# How many members does that family have?

# 6. Choose that family from the counts we already computed.

family_count[top_family]
# Out:
# 3

# %%
# What percent of total is that?

# 7. Compute a total
# 8. Compute the percent

total = family_count.sum()
pct = family_count[top_family] / total

pct
# Out:
# 0.6

# %% [markdown]
# ---
#
# ### E12.01
#
# How many columns are there in this data frame?

# %%
df.head()
# Out:
#   Facility ID                    Facility Name                     Address  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1      010005         MARSHALL MEDICAL CENTERS  2505 U S HIGHWAY 431 NORTH
# 2      010006     NORTH ALABAMA MEDICAL CENTER         1701 VETERANS DRIVE
# 3      010007         MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 4      010008      CRENSHAW COMMUNITY HOSPITAL         101 HOSPITAL CIRCLE
#
#        City State  ZIP Code County Name    Phone Number         Hospital Type  \
# 0    DOTHAN    AL     36301     HOUSTON  (334) 793-8701  Acute Care Hospitals
# 1      BOAZ    AL     35957    MARSHALL  (256) 593-8310  Acute Care Hospitals
# 2  FLORENCE    AL     35630  LAUDERDALE  (256) 768-8400  Acute Care Hospitals
# 3       OPP    AL     36467   COVINGTON  (334) 493-3541  Acute Care Hospitals
# 4   LUVERNE    AL     36049    CRENSHAW  (334) 335-3374  Acute Care Hospitals
#
#                             Hospital Ownership  ...  \
# 0  Government - Hospital District or Authority  ...
# 1  Government - Hospital District or Authority  ...
# 2                                  Proprietary  ...
# 3               Voluntary non-profit - Private  ...
# 4                                  Proprietary  ...
#
#   Count of READM Measures Better Count of READM Measures No Different  \
# 0                              0                                   10
# 1                              0                                   10
# 2                              0                                    8
# 3                              0                                    6
# 4                              0                                    4
#
#   Count of READM Measures Worse READM Group Footnote  \
# 0                             1                  NaN
# 1                             0                  NaN
# 2                             1                  NaN
# 3                             0                  NaN
# 4                             0                  NaN
#
#   Pt Exp Group Measure Count Count of Facility Pt Exp Measures  \
# 0                          8                                 8
# 1                          8                                 8
# 2                          8                                 8
# 3                          8                                 8
# 4                          8                     Not Available
#
#   Pt Exp Group Footnote TE Group Measure Count Count of Facility TE Measures  \
# 0                   NaN                     12                             9
# 1                   NaN                     12                            11
# 2                   NaN                     12                             9
# 3                   NaN                     12                             5
# 4                     5                     12                             5
#
#   TE Group Footnote
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 38 columns]

# %%
answers['E12.01'] = "38"

# %% [markdown]
# ### E12.02
#
# How many hospitals are there in this file? (Each row is one hospital.)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5307 entries, 0 to 5306
# Data columns (total 38 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Facility ID                                            5307 non-null   object
#  1   Facility Name                                          5307 non-null   object
#  2   Address                                                5307 non-null   object
#  3   City                                                   5307 non-null   object
#  4   State                                                  5307 non-null   object
#  5   ZIP Code                                               5307 non-null   int64
#  6   County Name                                            5307 non-null   object
#  7   Phone Number                                           5307 non-null   object
#  8   Hospital Type                                          5307 non-null   object
#  9   Hospital Ownership                                     5307 non-null   object
#  10  Emergency Services                                     5307 non-null   object
#  11  Meets criteria for promoting interoperability of EHRs  3968 non-null   object
#  12  Hospital overall rating                                5307 non-null   object
#  13  Hospital overall rating footnote                       2252 non-null   object
#  14  MORT Group Measure Count                               5307 non-null   object
#  15  Count of Facility MORT Measures                        5307 non-null   object
#  16  Count of MORT Measures Better                          5307 non-null   object
#  17  Count of MORT Measures No Different                    5307 non-null   object
#  18  Count of MORT Measures Worse                           5307 non-null   object
#  19  MORT Group Footnote                                    1520 non-null   object
#  20  Safety Group Measure Count                             5307 non-null   object
#  21  Count of Facility Safety Measures                      5307 non-null   object
#  22  Count of Safety Measures Better                        5307 non-null   object
#  23  Count of Safety Measures No Different                  5307 non-null   object
#  24  Count of Safety Measures Worse                         5307 non-null   object
#  25  Safety Group Footnote                                  1810 non-null   object
#  26  READM Group Measure Count                              5307 non-null   object
#  27  Count of Facility READM Measures                       5307 non-null   object
#  28  Count of READM Measures Better                         5307 non-null   object
#  29  Count of READM Measures No Different                   5307 non-null   object
#  30  Count of READM Measures Worse                          5307 non-null   object
#  31  READM Group Footnote                                   1139 non-null   object
#  32  Pt Exp Group Measure Count                             5307 non-null   object
#  33  Count of Facility Pt Exp Measures                      5307 non-null   object
#  34  Pt Exp Group Footnote                                  2053 non-null   object
#  35  TE Group Measure Count                                 5307 non-null   object
#  36  Count of Facility TE Measures                          5307 non-null   object
#  37  TE Group Footnote                                      1011 non-null   object
# dtypes: int64(1), object(37)
# memory usage: 1.5+ MB

# %%
answers['E12.02'] = "5307"

# %% [markdown]
# ### E12.03
#
# How many hospitals from Missouri (state abbreviation MO) are in this file?

# %%
df['State'].value_counts()
# Out:
# TX    457
# CA    372
# FL    208
# OH    195
# IL    190
# NY    184
# PA    183
# LA    158
# GA    147
# IN    146
# MI    143
# WI    138
# KS    138
# MN    136
# OK    131
# MO    119
# TN    118
# IA    117
# NC    117
# MS    103
# WA    102
# KY    101
# AZ    100
# AL     98
# VA     93
# CO     93
# NE     91
# AR     86
# MA     79
# NJ     79
# SC     67
# MT     63
# OR     62
# SD     59
# PR     58
# MD     55
# UT     52
# WV     50
# NM     47
# ID     47
# NV     46
# ND     46
# ME     37
# CT     36
# NH     28
# WY     27
# AK     25
# HI     25
# VT     16
# RI     12
# DE     12
# DC      9
# VI      2
# GU      2
# AS      1
# MP      1
# Name: State, dtype: int64

# %%
answers['E12.03'] = "119"

# %% [markdown]
# ### E12.04
#
# How many different ZIP Codes from Misouri are represented in this file?

# %%
filter = df ['State'] == 'MO'
mo_zipcode = df[filter]
mo_zipcode.head()
mo_zipcode['ZIP Code'].value_counts()
# Out:
# 63110    3
# 64108    3
# 65251    2
# 64116    2
# 63141    2
#         ..
# 64683    1
# 65708    1
# 64429    1
# 65613    1
# 65536    1
# Name: ZIP Code, Length: 109, dtype: int64

# %%
answers['E12.04'] = "109"

# %% [markdown]
# ### E12.05
#
# Which of those ZIP Codes has the most hospitals?  If it's a tie, submit your answer as a list of ZIP Codes.  Make sure your answer is submitted as a string or list of strings. Do not submit the ZIP Code values as numbers.

# %%
answers['E12.05'] = ""

# %% [markdown]
# ### E12.06
#
# Which state has the most hospitals?

# %%
df.groupby(['State']).count()
# Out:
#        Facility ID  Facility Name  Address  City  ZIP Code  County Name  \
# State
# AK              25             25       25    25        25           25
# AL              98             98       98    98        98           98
# AR              86             86       86    86        86           86
# AS               1              1        1     1         1            1
# AZ             100            100      100   100       100          100
# CA             372            372      372   372       372          372
# CO              93             93       93    93        93           93
# CT              36             36       36    36        36           36
# DC               9              9        9     9         9            9
# DE              12             12       12    12        12           12
# FL             208            208      208   208       208          208
# GA             147            147      147   147       147          147
# GU               2              2        2     2         2            2
# HI              25             25       25    25        25           25
# IA             117            117      117   117       117          117
# ID              47             47       47    47        47           47
# IL             190            190      190   190       190          190
# IN             146            146      146   146       146          146
# KS             138            138      138   138       138          138
# KY             101            101      101   101       101          101
# LA             158            158      158   158       158          158
# MA              79             79       79    79        79           79
# MD              55             55       55    55        55           55
# ME              37             37       37    37        37           37
# MI             143            143      143   143       143          143
# MN             136            136      136   136       136          136
# MO             119            119      119   119       119          119
# MP               1              1        1     1         1            1
# MS             103            103      103   103       103          103
# MT              63             63       63    63        63           63
# NC             117            117      117   117       117          117
# ND              46             46       46    46        46           46
# NE              91             91       91    91        91           91
# NH              28             28       28    28        28           28
# NJ              79             79       79    79        79           79
# NM              47             47       47    47        47           47
# NV              46             46       46    46        46           46
# NY             184            184      184   184       184          184
# OH             195            195      195   195       195          195
# OK             131            131      131   131       131          131
# OR              62             62       62    62        62           62
# PA             183            183      183   183       183          183
# PR              58             58       58    58        58           58
# RI              12             12       12    12        12           12
# SC              67             67       67    67        67           67
# SD              59             59       59    59        59           59
# TN             118            118      118   118       118          118
# TX             457            457      457   457       457          457
# UT              52             52       52    52        52           52
# VA              93             93       93    93        93           93
# VI               2              2        2     2         2            2
# VT              16             16       16    16        16           16
# WA             102            102      102   102       102          102
# WI             138            138      138   138       138          138
# WV              50             50       50    50        50           50
# WY              27             27       27    27        27           27
#
#        Phone Number  Hospital Type  Hospital Ownership  Emergency Services  \
# State
# AK               25             25                  25                  25
# AL               98             98                  98                  98
# AR               86             86                  86                  86
# AS                1              1                   1                   1
# AZ              100            100                 100                 100
# CA              372            372                 372                 372
# CO               93             93                  93                  93
# CT               36             36                  36                  36
# DC                9              9                   9                   9
# DE               12             12                  12                  12
# FL              208            208                 208                 208
# GA              147            147                 147                 147
# GU                2              2                   2                   2
# HI               25             25                  25                  25
# IA              117            117                 117                 117
# ID               47             47                  47                  47
# IL              190            190                 190                 190
# IN              146            146                 146                 146
# KS              138            138                 138                 138
# KY              101            101                 101                 101
# LA              158            158                 158                 158
# MA               79             79                  79                  79
# MD               55             55                  55                  55
# ME               37             37                  37                  37
# MI              143            143                 143                 143
# MN              136            136                 136                 136
# MO              119            119                 119                 119
# MP                1              1                   1                   1
# MS              103            103                 103                 103
# MT               63             63                  63                  63
# NC              117            117                 117                 117
# ND               46             46                  46                  46
# NE               91             91                  91                  91
# NH               28             28                  28                  28
# NJ               79             79                  79                  79
# NM               47             47                  47                  47
# NV               46             46                  46                  46
# NY              184            184                 184                 184
# OH              195            195                 195                 195
# OK              131            131                 131                 131
# OR               62             62                  62                  62
# PA              183            183                 183                 183
# PR               58             58                  58                  58
# RI               12             12                  12                  12
# SC               67             67                  67                  67
# SD               59             59                  59                  59
# TN              118            118                 118                 118
# TX              457            457                 457                 457
# UT               52             52                  52                  52
# VA               93             93                  93                  93
# VI                2              2                   2                   2
# VT               16             16                  16                  16
# WA              102            102                 102                 102
# WI              138            138                 138                 138
# WV               50             50                  50                  50
# WY               27             27                  27                  27
#
#        ...  Count of READM Measures Better  \
# State  ...
# AK     ...                              25
# AL     ...                              98
# AR     ...                              86
# AS     ...                               1
# AZ     ...                             100
# CA     ...                             372
# CO     ...                              93
# CT     ...                              36
# DC     ...                               9
# DE     ...                              12
# FL     ...                             208
# GA     ...                             147
# GU     ...                               2
# HI     ...                              25
# IA     ...                             117
# ID     ...                              47
# IL     ...                             190
# IN     ...                             146
# KS     ...                             138
# KY     ...                             101
# LA     ...                             158
# MA     ...                              79
# MD     ...                              55
# ME     ...                              37
# MI     ...                             143
# MN     ...                             136
# MO     ...                             119
# MP     ...                               1
# MS     ...                             103
# MT     ...                              63
# NC     ...                             117
# ND     ...                              46
# NE     ...                              91
# NH     ...                              28
# NJ     ...                              79
# NM     ...                              47
# NV     ...                              46
# NY     ...                             184
# OH     ...                             195
# OK     ...                             131
# OR     ...                              62
# PA     ...                             183
# PR     ...                              58
# RI     ...                              12
# SC     ...                              67
# SD     ...                              59
# TN     ...                             118
# TX     ...                             457
# UT     ...                              52
# VA     ...                              93
# VI     ...                               2
# VT     ...                              16
# WA     ...                             102
# WI     ...                             138
# WV     ...                              50
# WY     ...                              27
#
#        Count of READM Measures No Different  Count of READM Measures Worse  \
# State
# AK                                       25                             25
# AL                                       98                             98
# AR                                       86                             86
# AS                                        1                              1
# AZ                                      100                            100
# CA                                      372                            372
# CO                                       93                             93
# CT                                       36                             36
# DC                                        9                              9
# DE                                       12                             12
# FL                                      208                            208
# GA                                      147                            147
# GU                                        2                              2
# HI                                       25                             25
# IA                                      117                            117
# ID                                       47                             47
# IL                                      190                            190
# IN                                      146                            146
# KS                                      138                            138
# KY                                      101                            101
# LA                                      158                            158
# MA                                       79                             79
# MD                                       55                             55
# ME                                       37                             37
# MI                                      143                            143
# MN                                      136                            136
# MO                                      119                            119
# MP                                        1                              1
# MS                                      103                            103
# MT                                       63                             63
# NC                                      117                            117
# ND                                       46                             46
# NE                                       91                             91
# NH                                       28                             28
# NJ                                       79                             79
# NM                                       47                             47
# NV                                       46                             46
# NY                                      184                            184
# OH                                      195                            195
# OK                                      131                            131
# OR                                       62                             62
# PA                                      183                            183
# PR                                       58                             58
# RI                                       12                             12
# SC                                       67                             67
# SD                                       59                             59
# TN                                      118                            118
# TX                                      457                            457
# UT                                       52                             52
# VA                                       93                             93
# VI                                        2                              2
# VT                                       16                             16
# WA                                      102                            102
# WI                                      138                            138
# WV                                       50                             50
# WY                                       27                             27
#
#        READM Group Footnote  Pt Exp Group Measure Count  \
# State
# AK                       10                          25
# AL                       17                          98
# AR                       16                          86
# AS                        1                           1
# AZ                       32                         100
# CA                       68                         372
# CO                       18                          93
# CT                        9                          36
# DC                        3                           9
# DE                        6                          12
# FL                       38                         208
# GA                       33                         147
# GU                        1                           2
# HI                       12                          25
# IA                        7                         117
# ID                       13                          47
# IL                       22                         190
# IN                       32                         146
# KS                       25                         138
# KY                       13                         101
# LA                       60                         158
# MA                       21                          79
# MD                       10                          55
# ME                        5                          37
# MI                       18                         143
# MN                       39                         136
# MO                       19                         119
# MP                        0                           1
# MS                       23                         103
# MT                       24                          63
# NC                       15                         117
# ND                       14                          46
# NE                       11                          91
# NH                        2                          28
# NJ                       16                          79
# NM                       10                          47
# NV                       15                          46
# NY                       36                         184
# OH                       48                         195
# OK                       27                         131
# OR                        5                          62
# PA                       42                         183
# PR                       16                          58
# RI                        2                          12
# SC                       10                          67
# SD                       11                          59
# TN                       28                         118
# TX                      145                         457
# UT                        8                          52
# VA                       17                          93
# VI                        0                           2
# VT                        2                          16
# WA                       27                         102
# WI                       23                         138
# WV                       10                          50
# WY                        4                          27
#
#        Count of Facility Pt Exp Measures  Pt Exp Group Footnote  \
# State
# AK                                    25                     15
# AL                                    98                     30
# AR                                    86                     42
# AS                                     1                      1
# AZ                                   100                     40
# CA                                   372                     86
# CO                                    93                     36
# CT                                    36                     10
# DC                                     9                      3
# DE                                    12                      6
# FL                                   208                     50
# GA                                   147                     57
# GU                                     2                      2
# HI                                    25                     13
# IA                                   117                     58
# ID                                    47                     21
# IL                                   190                     62
# IN                                   146                     51
# KS                                   138                     89
# KY                                   101                     38
# LA                                   158                     87
# MA                                    79                     24
# MD                                    55                     14
# ME                                    37                      8
# MI                                   143                     40
# MN                                   136                     58
# MO                                   119                     39
# MP                                     1                      1
# MS                                   103                     56
# MT                                    63                     41
# NC                                   117                     28
# ND                                    46                     37
# NE                                    91                     59
# NH                                    28                      6
# NJ                                    79                     17
# NM                                    47                     20
# NV                                    46                     22
# NY                                   184                     50
# OH                                   195                     66
# OK                                   131                     68
# OR                                    62                     14
# PA                                   183                     48
# PR                                    58                     55
# RI                                    12                      2
# SC                                    67                     19
# SD                                    59                     43
# TN                                   118                     45
# TX                                   457                    215
# UT                                    52                     18
# VA                                    93                     22
# VI                                     2                      0
# VT                                    16                      4
# WA                                   102                     44
# WI                                   138                     43
# WV                                    50                     18
# WY                                    27                     12
#
#        TE Group Measure Count  Count of Facility TE Measures  \
# State
# AK                         25                             25
# AL                         98                             98
# AR                         86                             86
# AS                          1                              1
# AZ                        100                            100
# CA                        372                            372
# CO                         93                             93
# CT                         36                             36
# DC                          9                              9
# DE                         12                             12
# FL                        208                            208
# GA                        147                            147
# GU                          2                              2
# HI                         25                             25
# IA                        117                            117
# ID                         47                             47
# IL                        190                            190
# IN                        146                            146
# KS                        138                            138
# KY                        101                            101
# LA                        158                            158
# MA                         79                             79
# MD                         55                             55
# ME                         37                             37
# MI                        143                            143
# MN                        136                            136
# MO                        119                            119
# MP                          1                              1
# MS                        103                            103
# MT                         63                             63
# NC                        117                            117
# ND                         46                             46
# NE                         91                             91
# NH                         28                             28
# NJ                         79                             79
# NM                         47                             47
# NV                         46                             46
# NY                        184                            184
# OH                        195                            195
# OK                        131                            131
# OR                         62                             62
# PA                        183                            183
# PR                         58                             58
# RI                         12                             12
# SC                         67                             67
# SD                         59                             59
# TN                        118                            118
# TX                        457                            457
# UT                         52                             52
# VA                         93                             93
# VI                          2                              2
# VT                         16                             16
# WA                        102                            102
# WI                        138                            138
# WV                         50                             50
# WY                         27                             27
#
#        TE Group Footnote
# State
# AK                     5
# AL                    13
# AR                    15
# AS                     1
# AZ                    34
# CA                    68
# CO                    14
# CT                    10
# DC                     3
# DE                     6
# FL                    38
# GA                    20
# GU                     1
# HI                     4
# IA                    10
# ID                     5
# IL                    23
# IN                    31
# KS                    12
# KY                    11
# LA                    64
# MA                    22
# MD                    12
# ME                     4
# MI                    18
# MN                    15
# MO                    17
# MP                     1
# MS                    23
# MT                    12
# NC                    18
# ND                     4
# NE                     6
# NH                     2
# NJ                    16
# NM                     9
# NV                    13
# NY                    34
# OH                    47
# OK                    22
# OR                     4
# PA                    44
# PR                    31
# RI                     2
# SC                    11
# SD                     9
# TN                    25
# TX                   121
# UT                     7
# VA                    16
# VI                     1
# VT                     3
# WA                    22
# WI                    21
# WV                     6
# WY                     5
#
# [56 rows x 37 columns]

# %%
answers['E12.06'] = "TX"

# %% [markdown]
# ### E12.07
#
# How many different Hospital Types are there in this file?

# %%
df.groupby(['Hospital Type']).count()
# Out:
#                                     Facility ID  Facility Name  Address  City  \
# Hospital Type
# Acute Care - Department of Defense           35             35       35    35
# Acute Care Hospitals                       3223           3223     3223  3223
# Childrens                                    91             91       91    91
# Critical Access Hospitals                  1359           1359     1359  1359
# Psychiatric                                 599            599      599   599
#
#                                     State  ZIP Code  County Name  \
# Hospital Type
# Acute Care - Department of Defense     35        35           35
# Acute Care Hospitals                 3223      3223         3223
# Childrens                              91        91           91
# Critical Access Hospitals            1359      1359         1359
# Psychiatric                           599       599          599
#
#                                     Phone Number  Hospital Ownership  \
# Hospital Type
# Acute Care - Department of Defense            35                  35
# Acute Care Hospitals                        3223                3223
# Childrens                                     91                  91
# Critical Access Hospitals                   1359                1359
# Psychiatric                                  599                 599
#
#                                     Emergency Services  ...  \
# Hospital Type                                           ...
# Acute Care - Department of Defense                  35  ...
# Acute Care Hospitals                              3223  ...
# Childrens                                           91  ...
# Critical Access Hospitals                         1359  ...
# Psychiatric                                        599  ...
#
#                                     Count of READM Measures Better  \
# Hospital Type
# Acute Care - Department of Defense                              35
# Acute Care Hospitals                                          3223
# Childrens                                                       91
# Critical Access Hospitals                                     1359
# Psychiatric                                                    599
#
#                                     Count of READM Measures No Different  \
# Hospital Type
# Acute Care - Department of Defense                                    35
# Acute Care Hospitals                                                3223
# Childrens                                                             91
# Critical Access Hospitals                                           1359
# Psychiatric                                                          599
#
#                                     Count of READM Measures Worse  \
# Hospital Type
# Acute Care - Department of Defense                             35
# Acute Care Hospitals                                         3223
# Childrens                                                      91
# Critical Access Hospitals                                    1359
# Psychiatric                                                   599
#
#                                     READM Group Footnote  \
# Hospital Type
# Acute Care - Department of Defense                    35
# Acute Care Hospitals                                 132
# Childrens                                             91
# Critical Access Hospitals                            282
# Psychiatric                                          599
#
#                                     Pt Exp Group Measure Count  \
# Hospital Type
# Acute Care - Department of Defense                          35
# Acute Care Hospitals                                      3223
# Childrens                                                   91
# Critical Access Hospitals                                 1359
# Psychiatric                                                599
#
#                                     Count of Facility Pt Exp Measures  \
# Hospital Type
# Acute Care - Department of Defense                                 35
# Acute Care Hospitals                                             3223
# Childrens                                                          91
# Critical Access Hospitals                                        1359
# Psychiatric                                                       599
#
#                                     Pt Exp Group Footnote  \
# Hospital Type
# Acute Care - Department of Defense                     35
# Acute Care Hospitals                                  364
# Childrens                                              91
# Critical Access Hospitals                             964
# Psychiatric                                           599
#
#                                     TE Group Measure Count  \
# Hospital Type
# Acute Care - Department of Defense                      35
# Acute Care Hospitals                                  3223
# Childrens                                               91
# Critical Access Hospitals                             1359
# Psychiatric                                            599
#
#                                     Count of Facility TE Measures  \
# Hospital Type
# Acute Care - Department of Defense                             35
# Acute Care Hospitals                                         3223
# Childrens                                                      91
# Critical Access Hospitals                                    1359
# Psychiatric                                                   599
#
#                                     TE Group Footnote
# Hospital Type
# Acute Care - Department of Defense                 35
# Acute Care Hospitals                              160
# Childrens                                          91
# Critical Access Hospitals                         126
# Psychiatric                                       599
#
# [5 rows x 37 columns]

# %%
answers['E12.07'] = "5"

# %% [markdown]
# ### E12.08
#
# Which Hospital Type has the greatest number of files?

# %%
df.groupby(['Hospital Type']).count()
# Out:
#                                     Facility ID  Facility Name  Address  City  \
# Hospital Type
# Acute Care - Department of Defense           35             35       35    35
# Acute Care Hospitals                       3223           3223     3223  3223
# Childrens                                    91             91       91    91
# Critical Access Hospitals                  1359           1359     1359  1359
# Psychiatric                                 599            599      599   599
#
#                                     State  ZIP Code  County Name  \
# Hospital Type
# Acute Care - Department of Defense     35        35           35
# Acute Care Hospitals                 3223      3223         3223
# Childrens                              91        91           91
# Critical Access Hospitals            1359      1359         1359
# Psychiatric                           599       599          599
#
#                                     Phone Number  Hospital Ownership  \
# Hospital Type
# Acute Care - Department of Defense            35                  35
# Acute Care Hospitals                        3223                3223
# Childrens                                     91                  91
# Critical Access Hospitals                   1359                1359
# Psychiatric                                  599                 599
#
#                                     Emergency Services  ...  \
# Hospital Type                                           ...
# Acute Care - Department of Defense                  35  ...
# Acute Care Hospitals                              3223  ...
# Childrens                                           91  ...
# Critical Access Hospitals                         1359  ...
# Psychiatric                                        599  ...
#
#                                     Count of READM Measures Better  \
# Hospital Type
# Acute Care - Department of Defense                              35
# Acute Care Hospitals                                          3223
# Childrens                                                       91
# Critical Access Hospitals                                     1359
# Psychiatric                                                    599
#
#                                     Count of READM Measures No Different  \
# Hospital Type
# Acute Care - Department of Defense                                    35
# Acute Care Hospitals                                                3223
# Childrens                                                             91
# Critical Access Hospitals                                           1359
# Psychiatric                                                          599
#
#                                     Count of READM Measures Worse  \
# Hospital Type
# Acute Care - Department of Defense                             35
# Acute Care Hospitals                                         3223
# Childrens                                                      91
# Critical Access Hospitals                                    1359
# Psychiatric                                                   599
#
#                                     READM Group Footnote  \
# Hospital Type
# Acute Care - Department of Defense                    35
# Acute Care Hospitals                                 132
# Childrens                                             91
# Critical Access Hospitals                            282
# Psychiatric                                          599
#
#                                     Pt Exp Group Measure Count  \
# Hospital Type
# Acute Care - Department of Defense                          35
# Acute Care Hospitals                                      3223
# Childrens                                                   91
# Critical Access Hospitals                                 1359
# Psychiatric                                                599
#
#                                     Count of Facility Pt Exp Measures  \
# Hospital Type
# Acute Care - Department of Defense                                 35
# Acute Care Hospitals                                             3223
# Childrens                                                          91
# Critical Access Hospitals                                        1359
# Psychiatric                                                       599
#
#                                     Pt Exp Group Footnote  \
# Hospital Type
# Acute Care - Department of Defense                     35
# Acute Care Hospitals                                  364
# Childrens                                              91
# Critical Access Hospitals                             964
# Psychiatric                                           599
#
#                                     TE Group Measure Count  \
# Hospital Type
# Acute Care - Department of Defense                      35
# Acute Care Hospitals                                  3223
# Childrens                                               91
# Critical Access Hospitals                             1359
# Psychiatric                                            599
#
#                                     Count of Facility TE Measures  \
# Hospital Type
# Acute Care - Department of Defense                             35
# Acute Care Hospitals                                         3223
# Childrens                                                      91
# Critical Access Hospitals                                    1359
# Psychiatric                                                   599
#
#                                     TE Group Footnote
# Hospital Type
# Acute Care - Department of Defense                 35
# Acute Care Hospitals                              160
# Childrens                                          91
# Critical Access Hospitals                         126
# Psychiatric                                       599
#
# [5 rows x 37 columns]

# %%
answers['E12.08'] = "Acute Care Hospitals"

# %% [markdown]
# ### E12.09
#
# What percent of the total hospital count (represented as ##.##%, rounded to two decimal places) is represented in that Hospital Type?

# %%
answers['E12.09'] = ""

# %% [markdown]
# ### E12.10
#
# What percent of the total hospital count (represented as ##.##%, rounded to two decimal places) provide Emergency Services?

# %%
answers['E12.10'] = ""

# %% [markdown]
# ---
#
# Checking Your Work
# ---
#
# After completing your work above and running each cell, you can check your answers by running the code below.
#
# The easiest way to do this is to use the `Kernel` -> `Restart Kernel and Run All Cells` menu option. This option restarts Python and runs every cell from top to bottom until it encounters an exception of some kind.  It will stop after running the cell below and outputing a summary of how many answers you have correct or incorrect.

# %%
import getpass
import boto3
import json

test = {
    "user": getpass.getuser(),
    "week": "week12EB",
    "answers": answers
}

client = boto3.client('lambda')

response = client.invoke(
    FunctionName="hds5210",
    InvocationType="RequestResponse",
    Payload=json.dumps(test))

result = json.loads(response['Payload'].read().decode('utf-8'))
# print(result)

try:
    print('{0:>7}{1:>30}{2:>10}'.format('Q#','Yours','Correct?'))
    for row in result.get('results'):
        print('{0:>7}{1:>30}{2:>10}'.format(str(row[0]),str(row[1]),str(row[2])))
except:
    print(result)
# Out:
#      Q#                         Yours  Correct?
#  E12.01                            38        OK
#  E12.02                          5307        OK
#  E12.03                           119        OK
#  E12.04                           109        OK
#  E12.05                                      NO
#  E12.06                            TX        OK
#  E12.07                             5        OK
#  E12.08          Acute Care Hospitals        OK
#  E12.09                                      NO
#  E12.10                                      NO

# %% [markdown]
# ## Submit your work to github in your week 13 folder by 12/5 11:59 PM
